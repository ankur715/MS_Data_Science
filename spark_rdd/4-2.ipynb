# %%
### Convert Temperature Data

# %%
# Parallelizing the Data 
tempData = [59,57.2,53.6,55.4,51.8,53.6,55.4]
parTempData = sc.parallelize(tempData,3)
print(parTempData.collect())
parTempData.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[59, 57.2, 53.6, 55.4, 51.8, 53.6, 55.4]
# <span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>3
# </div>

# %%
# Converting Temperature from Fahrenheit to Celsius 
def fahrenheitToCentigrade(temperature):
  centigrade = (temperature-32)*5/9
  return centigrade
fahrenheitToCentigrade(59)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>15.0
# </div>

# %%
parCentigradeData = parTempData.map(fahrenheitToCentigrade)
parCentigradeData.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>[15.0, 14.000000000000002, 12.0, 13.0, 10.999999999999998, 12.0, 13.0]
# </div>

# %%
# Filtering Temperatures Greater than 13o C 
def tempMoreThanThirteen(temperature):
  return temperature >=13
filteredTemperature = parCentigradeData.filter(tempMoreThanThirteen)
filteredTemperature.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>[15.0, 14.000000000000002, 13.0, 13.0]
# </div>

# %%
filteredTemperature = parCentigradeData.filter(lambda x : x<13)
filteredTemperature.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>[12.0, 10.999999999999998, 12.0]
# </div>
