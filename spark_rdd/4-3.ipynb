# %%
### Perform Basic Data Manipulation

# %%
# Making a List from a Given Table
studentMarksData = [["si1","year1",62.08,62.4], 
                    ["si1","year2",75.94,76.75],
                    ["si2","year1",68.26,72.95],
                    ["si2","year2",85.49,75.8], 
                    ["si3","year1",75.08,79.84], 
                    ["si3","year2",54.98,87.72],
                    ["si4","year1",50.03,66.85],
                    ["si4","year2",71.26,69.77],
                    ["si5","year1",52.74,76.27],
                    ["si5","year2",50.39,68.58],
                    ["si6","year1",74.86,60.8],
                    ["si6","year2",58.29,62.38],
                    ["si7","year1",63.95,74.51],
                    ["si7","year2",66.69,56.92]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Parallelizing the Data
studentMarksDataRDD = sc.parallelize(studentMarksData,4)
studentMarksDataRDD.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Calculating Average Semester Grades
studentMarksMean = studentMarksDataRDD.map(lambda x : [x[0],x[1],(x[2]+x[3])/2])
studentMarksMean.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Filtering Student Average Grades in the Second Year
secondYearMarks = studentMarksMean.filter(lambda x : "year2" in x)
secondYearMarks.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>[[&apos;si1&apos;, &apos;year2&apos;, 76.345], [&apos;si2&apos;, &apos;year2&apos;, 80.645]]
# </div>

# %%
# Finding the Top Three Students 
sortedMarksData = secondYearMarks.sortBy(keyfunc = lambda x : -x[2])
print(sortedMarksData.collect())
print(sortedMarksData.take(3))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[[&apos;si2&apos;, &apos;year2&apos;, 80.645], [&apos;si1&apos;, &apos;year2&apos;, 76.345], [&apos;si3&apos;, &apos;year2&apos;, 71.35], [&apos;si4&apos;, &apos;year2&apos;, 70.515], [&apos;si7&apos;, &apos;year2&apos;, 61.805], [&apos;si6&apos;, &apos;year2&apos;, 60.335], [&apos;si5&apos;, &apos;year2&apos;, 59.485]]
# [[&apos;si2&apos;, &apos;year2&apos;, 80.645], [&apos;si1&apos;, &apos;year2&apos;, 76.345], [&apos;si3&apos;, &apos;year2&apos;, 71.35]]
# </div>

# %%
topThreeStudents = secondYearMarks.takeOrdered(num=3, key = lambda x :-x[2])
topThreeStudents
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>[[&apos;si2&apos;, &apos;year2&apos;, 80.645], [&apos;si1&apos;, &apos;year2&apos;, 76.345], [&apos;si3&apos;, &apos;year2&apos;, 71.35]]
# </div>

# %%
# Finding the Bottom Three Students
bottomThreeStudents = secondYearMarks.takeOrdered(num=3, key = lambda x :x[2])
bottomThreeStudents
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>[[&apos;si5&apos;, &apos;year2&apos;, 59.485], [&apos;si6&apos;, &apos;year2&apos;, 60.335], [&apos;si7&apos;, &apos;year2&apos;, 61.805]]
# </div>

# %%
# Getting All Students with 80% Averages 
moreThan80Marks = secondYearMarks.filter(lambda x : x[2] > 80)
moreThan80Marks.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">20</span><span class="ansired">]: </span>[[&apos;si2&apos;, &apos;year2&apos;, 80.645]]
# </div>
