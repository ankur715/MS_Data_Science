# %%
### Run Set Operations

# %%
# Creating a List of Research Data by Year
data2001 = ['RIN1', 'RIN2', 'RIN3', 'RIN4', 'RIN5', 'RIN6', 'RIN7']
data2002 = ['RIN3', 'RIN4', 'RIN7', 'RIN8', 'RIN9']
data2003 = ['RIN4', 'RIN8', 'RIN10', 'RIN11', 'RIN12']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Parallelizing the Data (Creating the RDD) 
parData2001 = sc.parallelize(data2001,2)
parData2002 = sc.parallelize(data2002,2)
parData2003 = sc.parallelize(data2003,2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Finding Projects Initiated in Three Years 
unionOf20012002 = parData2001.union(parData2002) 
unionOf20012002.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>
# [&apos;RIN1&apos;,
#  &apos;RIN2&apos;,
#  &apos;RIN3&apos;,
#  &apos;RIN4&apos;,
#  &apos;RIN5&apos;,
#  &apos;RIN6&apos;,
#  &apos;RIN7&apos;,
#  &apos;RIN3&apos;,
#  &apos;RIN4&apos;,
#  &apos;RIN7&apos;,
#  &apos;RIN8&apos;,
#  &apos;RIN9&apos;]
# </div>

# %%
allResearchs = unionOf20012002.union(parData2003)
allResearchs.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>
# [&apos;RIN1&apos;,
#  &apos;RIN2&apos;,
#  &apos;RIN3&apos;,
#  &apos;RIN4&apos;,
#  &apos;RIN5&apos;,
#  &apos;RIN6&apos;,
#  &apos;RIN7&apos;,
#  &apos;RIN3&apos;,
#  &apos;RIN4&apos;,
#  &apos;RIN7&apos;,
#  &apos;RIN8&apos;,
#  &apos;RIN9&apos;,
#  &apos;RIN4&apos;,
#  &apos;RIN8&apos;,
#  &apos;RIN10&apos;,
#  &apos;RIN11&apos;,
#  &apos;RIN12&apos;]
# </div>

# %%
# Making Sets of Distinct Data
allUniqueResearchs = allResearchs.distinct() 
allUniqueResearchs.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>
# [&apos;RIN12&apos;,
#  &apos;RIN1&apos;,
#  &apos;RIN10&apos;,
#  &apos;RIN2&apos;,
#  &apos;RIN5&apos;,
#  &apos;RIN8&apos;,
#  &apos;RIN3&apos;,
#  &apos;RIN11&apos;,
#  &apos;RIN4&apos;,
#  &apos;RIN9&apos;,
#  &apos;RIN6&apos;,
#  &apos;RIN7&apos;]
# </div>

# %%
# Counting Distinct Elements 
print(allResearchs.distinct().count())
parData2001.union(parData2002).union(parData2003).distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">12
# <span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>12
# </div>

# %%
# Finding Projects Completed the First Year 
firstYearCompletion = parData2001.subtract(parData2002)
firstYearCompletion.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>[&apos;RIN2&apos;, &apos;RIN1&apos;, &apos;RIN5&apos;, &apos;RIN6&apos;]
# </div>

# %%
# Finding Projects Completed in the First Two Years
unionTwoYears = parData2001.union(parData2002)
print(unionTwoYears.subtract(parData2003).collect())
unionTwoYears.subtract(parData2003).distinct().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&apos;RIN1&apos;, &apos;RIN2&apos;, &apos;RIN5&apos;, &apos;RIN3&apos;, &apos;RIN3&apos;, &apos;RIN9&apos;, &apos;RIN6&apos;, &apos;RIN7&apos;, &apos;RIN7&apos;]
# <span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>[&apos;RIN1&apos;, &apos;RIN2&apos;, &apos;RIN5&apos;, &apos;RIN3&apos;, &apos;RIN9&apos;, &apos;RIN6&apos;, &apos;RIN7&apos;]
# </div>

# %%
# Finding Projects Started in 2001 and Continued Through 2003
projectsInTwoYear = parData2001.intersection(parData2002)
print(projectsInTwoYear.collect())
projectsInTwoYear.subtract(parData2003).distinct().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&apos;RIN3&apos;, &apos;RIN4&apos;, &apos;RIN7&apos;]
# <span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>[&apos;RIN3&apos;, &apos;RIN7&apos;]
# </div>
